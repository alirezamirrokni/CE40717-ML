# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Alireza Mirrokni
# Student-ID: 401106617

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(
    x, y_new, train_size=60000, test_size=10000, random_state=42, stratify=y
)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'tanh':
            self.activation = self.tanh
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # -------------------------------- TODO -------------------------------------

        # Do the same for other activation functions

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return (x > 0).astype(float)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        tanh_val = np.tanh(x)
        if derivative:
            return 1 - tanh_val ** 2
        else:
            return tanh_val
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
            return sig * (1 - sig)
        else:
            return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exp_vals = np.exp(x - np.max(x, axis=0, keepdims=True))
        return exp_vals / np.sum(exp_vals, axis=0, keepdims=True)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha)
        else:
            return np.where(x > 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
            z = np.dot(self.params[f"W{i}"], self.cache[f"A{i-1}"]) + self.params[f"b{i}"]

            if i == self.num_layers:
                self.cache[f"A{i}"] = self.softmax(z)
            else:
                self.cache[f"A{i}"] = self.activation(z)
        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        dz = output - y.T
        grads[f"W{self.num_layers}"] = np.dot(dz, self.cache[f"A{self.num_layers-1}"].T) / current_batch_size
        grads[f"b{self.num_layers}"] = np.sum(dz, axis=1, keepdims=True) / current_batch_size

        for i in range(self.num_layers - 1, 0, -1):
            dz = np.dot(self.params[f"W{i+1}"].T, dz) * self.activation(self.cache[f"A{i}"], derivative=True)
            grads[f"W{i}"] = np.dot(dz, self.cache[f"A{i-1}"].T) / current_batch_size
            grads[f"b{i}"] = np.sum(dz, axis=1, keepdims=True) / current_batch_size
        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        return -np.mean(np.sum(y * np.log(output.T + 1e-8), axis=1))
        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"VdW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"Vdb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"VdW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"Vdb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"SdW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"Sdb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                if key.startswith("W"):
                    v_key = f"Vd{key}"
                    self.momemtum_opt[v_key] = beta * self.momemtum_opt[v_key] + (1 - beta) * self.grads[key]
                    self.params[key] -= l_rate * self.momemtum_opt[v_key]
                elif key.startswith("b"):
                    v_key = f"Vd{key}"
                    self.momemtum_opt[v_key] = beta * self.momemtum_opt[v_key] + (1 - beta) * self.grads[key]
                    self.params[key] -= l_rate * self.momemtum_opt[v_key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                if key.startswith("W") or key.startswith("b"):
                    v_key = f"Vd{key}"
                    s_key = f"Sd{key}"
                    self.adam_opt[v_key] = beta1 * self.adam_opt[v_key] + (1 - beta1) * self.grads[key]
                    self.adam_opt[s_key] = beta2 * self.adam_opt[s_key] + (1 - beta2) * (self.grads[key] ** 2)
                    v_corrected = self.adam_opt[v_key] / (1 - beta1 ** t)
                    s_corrected = self.adam_opt[s_key] / (1 - beta2 ** t)
                    self.params[key] -= l_rate * v_corrected / (np.sqrt(s_corrected) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        predictions = np.argmax(output, axis=0)
        labels = np.argmax(y, axis=1)
        return np.mean(predictions == labels)
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
x_train_split, x_val, y_train_split, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42, stratify=np.argmax(y_train, axis=1)
)

optimizers = ['sgd', 'momentum', 'adam']
activations = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
learning_rates = [0.01, 0.001]
network_sizes = [784, 128, 64, 10]

results = []

for optimizer in optimizers:
    for activation in activations:
        for lr in learning_rates:
            print(f"Training with optimizer={optimizer}, activation={activation}, learning_rate={lr}")
            model = MLP(network_sizes, activation=activation)

            model.train(
                x_train_split, y_train_split, x_val, y_val,
                epochs=20, batch_size=64, optimizer=optimizer, l_rate=lr
            )

            output = model.feed_forward(x_test)

            test_acc = model.accuracy(y_test, output)
            test_loss = model.cross_entropy_loss(y_test, output)
            results.append({'Optimizer': optimizer, 'Activation': activation, 'Learning Rate': lr,
                            'Test Accuracy': test_acc, 'Test Loss': test_loss})

            print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")
            print(100 * '-')

results_df = pd.DataFrame(results)

best_result = results_df.loc[results_df['Test Accuracy'].idxmax()]
print("Best Configuration:")
print(best_result)
# Out:
# Training with optimizer=sgd, activation=relu, learning_rate=0.01
# Epoch 1: 2.65s, train acc=0.87, train loss=0.53, validation acc=0.87, validation loss=0.53
# Epoch 2: 5.16s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 3: 10.39s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.33
# Epoch 4: 13.04s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 5: 15.55s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 18.10s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.26
# Epoch 7: 20.55s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 8: 25.65s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 9: 28.09s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.23
# Epoch 10: 30.62s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 11: 33.11s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 12: 35.51s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 13: 40.52s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.19
# Epoch 14: 42.88s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 15: 45.31s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 16: 47.79s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 17: 50.21s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 18: 55.51s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.15
# Epoch 19: 58.00s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 20: 60.56s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.15
# Test Accuracy: 0.9556, Test Loss: 0.1533
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=relu, learning_rate=0.001
# Epoch 1: 2.44s, train acc=0.34, train loss=2.17, validation acc=0.34, validation loss=2.17
# Epoch 2: 4.80s, train acc=0.52, train loss=1.98, validation acc=0.52, validation loss=1.98
# Epoch 3: 9.82s, train acc=0.67, train loss=1.71, validation acc=0.67, validation loss=1.70
# Epoch 4: 12.38s, train acc=0.75, train loss=1.40, validation acc=0.75, validation loss=1.39
# Epoch 5: 14.82s, train acc=0.79, train loss=1.11, validation acc=0.79, validation loss=1.11
# Epoch 6: 17.40s, train acc=0.81, train loss=0.91, validation acc=0.81, validation loss=0.90
# Epoch 7: 20.02s, train acc=0.83, train loss=0.77, validation acc=0.83, validation loss=0.76
# Epoch 8: 24.63s, train acc=0.84, train loss=0.68, validation acc=0.84, validation loss=0.67
# Epoch 9: 27.21s, train acc=0.85, train loss=0.61, validation acc=0.85, validation loss=0.60
# Epoch 10: 29.76s, train acc=0.86, train loss=0.56, validation acc=0.86, validation loss=0.56
# Epoch 11: 32.19s, train acc=0.87, train loss=0.52, validation acc=0.87, validation loss=0.52
# Epoch 12: 34.83s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.49
# Epoch 13: 39.53s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.47
# Epoch 14: 42.09s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.45
# Epoch 15: 44.61s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.43
# Epoch 16: 47.23s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 17: 50.99s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 18: 54.77s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 19: 57.29s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 20: 59.85s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Test Accuracy: 0.8938, Test Loss: 0.3801
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=sigmoid, learning_rate=0.01
# Epoch 1: 3.13s, train acc=0.12, train loss=2.26, validation acc=0.12, validation loss=2.26
# Epoch 2: 9.03s, train acc=0.43, train loss=2.21, validation acc=0.43, validation loss=2.21
# Epoch 3: 12.13s, train acc=0.50, train loss=2.12, validation acc=0.50, validation loss=2.12
# Epoch 4: 15.23s, train acc=0.58, train loss=1.96, validation acc=0.59, validation loss=1.96
# Epoch 5: 18.38s, train acc=0.63, train loss=1.71, validation acc=0.64, validation loss=1.70
# Epoch 6: 23.97s, train acc=0.67, train loss=1.43, validation acc=0.68, validation loss=1.43
# Epoch 7: 28.42s, train acc=0.70, train loss=1.21, validation acc=0.70, validation loss=1.21
# Epoch 8: 32.34s, train acc=0.73, train loss=1.05, validation acc=0.73, validation loss=1.05
# Epoch 9: 37.87s, train acc=0.75, train loss=0.94, validation acc=0.75, validation loss=0.93
# Epoch 10: 41.06s, train acc=0.77, train loss=0.85, validation acc=0.77, validation loss=0.84
# Epoch 11: 44.28s, train acc=0.79, train loss=0.78, validation acc=0.79, validation loss=0.77
# Epoch 12: 47.47s, train acc=0.80, train loss=0.72, validation acc=0.80, validation loss=0.71
# Epoch 13: 53.21s, train acc=0.81, train loss=0.67, validation acc=0.82, validation loss=0.67
# Epoch 14: 56.27s, train acc=0.83, train loss=0.63, validation acc=0.82, validation loss=0.63
# Epoch 15: 59.23s, train acc=0.83, train loss=0.60, validation acc=0.83, validation loss=0.60
# Epoch 16: 62.26s, train acc=0.84, train loss=0.58, validation acc=0.84, validation loss=0.57
# Epoch 17: 67.86s, train acc=0.85, train loss=0.55, validation acc=0.85, validation loss=0.55
# Epoch 18: 70.88s, train acc=0.85, train loss=0.53, validation acc=0.85, validation loss=0.53
# Epoch 19: 74.11s, train acc=0.86, train loss=0.52, validation acc=0.86, validation loss=0.51
# Epoch 20: 77.35s, train acc=0.86, train loss=0.50, validation acc=0.86, validation loss=0.50
# Test Accuracy: 0.8643, Test Loss: 0.4953
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=sigmoid, learning_rate=0.001
# Epoch 1: 5.87s, train acc=0.10, train loss=2.30, validation acc=0.10, validation loss=2.30
# Epoch 2: 8.91s, train acc=0.13, train loss=2.29, validation acc=0.13, validation loss=2.29
# Epoch 3: 11.92s, train acc=0.13, train loss=2.29, validation acc=0.13, validation loss=2.29
# Epoch 4: 15.06s, train acc=0.13, train loss=2.29, validation acc=0.13, validation loss=2.29
# Epoch 5: 21.05s, train acc=0.16, train loss=2.28, validation acc=0.16, validation loss=2.28
# Epoch 6: 24.00s, train acc=0.15, train loss=2.28, validation acc=0.16, validation loss=2.28
# Epoch 7: 27.00s, train acc=0.16, train loss=2.28, validation acc=0.16, validation loss=2.28
# Epoch 8: 30.11s, train acc=0.17, train loss=2.27, validation acc=0.17, validation loss=2.27
# Epoch 9: 35.83s, train acc=0.17, train loss=2.27, validation acc=0.17, validation loss=2.27
# Epoch 10: 38.89s, train acc=0.19, train loss=2.27, validation acc=0.20, validation loss=2.27
# Epoch 11: 41.87s, train acc=0.19, train loss=2.26, validation acc=0.19, validation loss=2.26
# Epoch 12: 44.85s, train acc=0.20, train loss=2.26, validation acc=0.20, validation loss=2.26
# Epoch 13: 50.52s, train acc=0.24, train loss=2.26, validation acc=0.24, validation loss=2.25
# Epoch 14: 53.51s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 15: 56.52s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 16: 59.65s, train acc=0.28, train loss=2.24, validation acc=0.28, validation loss=2.24
# Epoch 17: 65.40s, train acc=0.27, train loss=2.24, validation acc=0.28, validation loss=2.24
# Epoch 18: 68.45s, train acc=0.31, train loss=2.23, validation acc=0.31, validation loss=2.23
# Epoch 19: 71.61s, train acc=0.30, train loss=2.23, validation acc=0.31, validation loss=2.23
# Epoch 20: 74.71s, train acc=0.31, train loss=2.22, validation acc=0.32, validation loss=2.22
# Test Accuracy: 0.3165, Test Loss: 2.2201
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=tanh, learning_rate=0.01
# Epoch 1: 6.90s, train acc=0.87, train loss=0.54, validation acc=0.87, validation loss=0.53
# Epoch 2: 11.38s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 3: 16.76s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 4: 22.67s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.32
# Epoch 5: 27.05s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 6: 33.08s, train acc=0.92, train loss=0.29, validation acc=0.92, validation loss=0.29
# Epoch 7: 38.01s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.28
# Epoch 8: 42.58s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 9: 49.33s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.26
# Epoch 10: 53.95s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 11: 58.81s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 12: 65.58s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 13: 70.18s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 14: 76.16s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 15: 81.45s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 16: 86.04s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 17: 93.46s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 18: 98.03s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 19: 102.72s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 20: 109.56s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Test Accuracy: 0.9380, Test Loss: 0.2059
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=tanh, learning_rate=0.001
# Epoch 1: 4.79s, train acc=0.63, train loss=1.74, validation acc=0.63, validation loss=1.74
# Epoch 2: 11.26s, train acc=0.73, train loss=1.37, validation acc=0.73, validation loss=1.36
# Epoch 3: 16.13s, train acc=0.78, train loss=1.12, validation acc=0.78, validation loss=1.12
# Epoch 4: 20.68s, train acc=0.81, train loss=0.96, validation acc=0.81, validation loss=0.95
# Epoch 5: 27.90s, train acc=0.83, train loss=0.84, validation acc=0.83, validation loss=0.83
# Epoch 6: 32.39s, train acc=0.84, train loss=0.75, validation acc=0.84, validation loss=0.75
# Epoch 7: 36.87s, train acc=0.85, train loss=0.69, validation acc=0.85, validation loss=0.68
# Epoch 8: 44.32s, train acc=0.86, train loss=0.64, validation acc=0.86, validation loss=0.63
# Epoch 9: 50.14s, train acc=0.86, train loss=0.60, validation acc=0.86, validation loss=0.59
# Epoch 10: 57.20s, train acc=0.87, train loss=0.56, validation acc=0.87, validation loss=0.56
# Epoch 11: 61.99s, train acc=0.87, train loss=0.54, validation acc=0.87, validation loss=0.53
# Epoch 12: 67.67s, train acc=0.87, train loss=0.51, validation acc=0.88, validation loss=0.51
# Epoch 13: 73.49s, train acc=0.88, train loss=0.49, validation acc=0.88, validation loss=0.49
# Epoch 14: 78.22s, train acc=0.88, train loss=0.48, validation acc=0.88, validation loss=0.47
# Epoch 15: 85.24s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 16: 89.85s, train acc=0.88, train loss=0.45, validation acc=0.89, validation loss=0.45
# Epoch 17: 94.41s, train acc=0.89, train loss=0.44, validation acc=0.89, validation loss=0.43
# Epoch 18: 101.38s, train acc=0.89, train loss=0.43, validation acc=0.89, validation loss=0.42
# Epoch 19: 106.25s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.41
# Epoch 20: 112.17s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Test Accuracy: 0.8900, Test Loss: 0.4083
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 3.15s, train acc=0.86, train loss=0.53, validation acc=0.86, validation loss=0.53
# Epoch 2: 5.91s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 3: 8.53s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.33
# Epoch 4: 11.38s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 5: 16.37s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 19.14s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 7: 21.82s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 8: 24.46s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 9: 28.65s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 10: 32.62s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 11: 35.48s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 12: 38.14s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 13: 40.73s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 14: 46.02s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 15: 48.71s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 16: 51.48s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 17: 54.17s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 18: 57.82s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 19: 62.03s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.16
# Epoch 20: 64.65s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.16
# Test Accuracy: 0.9521, Test Loss: 0.1608
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 2.60s, train acc=0.41, train loss=2.15, validation acc=0.41, validation loss=2.15
# Epoch 2: 5.39s, train acc=0.64, train loss=1.92, validation acc=0.63, validation loss=1.92
# Epoch 3: 10.76s, train acc=0.73, train loss=1.61, validation acc=0.73, validation loss=1.61
# Epoch 4: 13.49s, train acc=0.78, train loss=1.26, validation acc=0.78, validation loss=1.26
# Epoch 5: 16.10s, train acc=0.81, train loss=1.00, validation acc=0.81, validation loss=1.00
# Epoch 6: 18.76s, train acc=0.83, train loss=0.83, validation acc=0.83, validation loss=0.82
# Epoch 7: 22.69s, train acc=0.84, train loss=0.71, validation acc=0.84, validation loss=0.71
# Epoch 8: 26.51s, train acc=0.85, train loss=0.64, validation acc=0.85, validation loss=0.63
# Epoch 9: 29.36s, train acc=0.86, train loss=0.58, validation acc=0.86, validation loss=0.58
# Epoch 10: 32.17s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.54
# Epoch 11: 36.90s, train acc=0.87, train loss=0.51, validation acc=0.87, validation loss=0.50
# Epoch 12: 43.94s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.48
# Epoch 13: 46.70s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 14: 49.55s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.44
# Epoch 15: 52.22s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.43
# Epoch 16: 56.87s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.41
# Epoch 17: 60.18s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 18: 62.82s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 19: 65.33s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.38
# Epoch 20: 68.02s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.38
# Test Accuracy: 0.8934, Test Loss: 0.3778
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=selu, learning_rate=0.01
# Epoch 1: 6.02s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.43
# Epoch 2: 11.16s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 3: 14.46s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.32
# Epoch 4: 20.53s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 5: 23.99s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.29
# Epoch 6: 27.41s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.28
# Epoch 7: 31.99s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 8: 36.67s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.26
# Epoch 9: 40.09s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.26
# Epoch 10: 43.44s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 11: 49.51s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 12: 52.95s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 13: 56.30s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 14: 59.91s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.23
# Epoch 15: 65.68s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 16: 68.99s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 17: 74.76s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 18: 80.88s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 19: 84.26s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 20: 87.64s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Test Accuracy: 0.9406, Test Loss: 0.2024
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=selu, learning_rate=0.001
# Epoch 1: 4.95s, train acc=0.74, train loss=1.27, validation acc=0.74, validation loss=1.26
# Epoch 2: 9.21s, train acc=0.81, train loss=0.88, validation acc=0.81, validation loss=0.87
# Epoch 3: 12.61s, train acc=0.84, train loss=0.71, validation acc=0.84, validation loss=0.70
# Epoch 4: 16.02s, train acc=0.85, train loss=0.61, validation acc=0.85, validation loss=0.60
# Epoch 5: 22.09s, train acc=0.86, train loss=0.55, validation acc=0.86, validation loss=0.54
# Epoch 6: 25.55s, train acc=0.87, train loss=0.51, validation acc=0.87, validation loss=0.50
# Epoch 7: 28.94s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.47
# Epoch 8: 32.87s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.44
# Epoch 9: 38.00s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.43
# Epoch 10: 41.39s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.41
# Epoch 11: 44.79s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 12: 50.18s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 13: 54.19s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 14: 57.64s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.37
# Epoch 15: 61.06s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
# Epoch 16: 67.23s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.36
# Epoch 17: 70.59s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 18: 73.94s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 19: 78.74s, train acc=0.90, train loss=0.34, validation acc=0.90, validation loss=0.34
# Epoch 20: 82.97s, train acc=0.91, train loss=0.34, validation acc=0.90, validation loss=0.34
# Test Accuracy: 0.9017, Test Loss: 0.3416
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=elu, learning_rate=0.01
# Epoch 1: 3.35s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.49
# Epoch 2: 6.64s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.37
# Epoch 3: 12.64s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.33
# Epoch 4: 15.99s, train acc=0.91, train loss=0.31, validation acc=0.91, validation loss=0.31
# Epoch 5: 19.30s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 6: 22.88s, train acc=0.92, train loss=0.29, validation acc=0.92, validation loss=0.29
# Epoch 7: 28.49s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 8: 31.92s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 9: 35.29s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 10: 40.11s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.26
# Epoch 11: 44.30s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.26
# Epoch 12: 47.67s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 13: 50.99s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 14: 56.98s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 15: 60.24s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 16: 63.66s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 17: 67.23s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 18: 73.14s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 19: 76.50s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 20: 79.93s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.21
# Test Accuracy: 0.9377, Test Loss: 0.2142
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=sgd, activation=elu, learning_rate=0.001
# Epoch 1: 4.89s, train acc=0.64, train loss=1.72, validation acc=0.65, validation loss=1.71
# Epoch 2: 9.88s, train acc=0.75, train loss=1.29, validation acc=0.75, validation loss=1.28
# Epoch 3: 13.34s, train acc=0.79, train loss=1.01, validation acc=0.79, validation loss=1.01
# Epoch 4: 17.52s, train acc=0.82, train loss=0.84, validation acc=0.82, validation loss=0.83
# Epoch 5: 26.02s, train acc=0.83, train loss=0.73, validation acc=0.83, validation loss=0.72
# Epoch 6: 29.37s, train acc=0.84, train loss=0.65, validation acc=0.84, validation loss=0.65
# Epoch 7: 34.20s, train acc=0.85, train loss=0.59, validation acc=0.85, validation loss=0.59
# Epoch 8: 38.36s, train acc=0.86, train loss=0.55, validation acc=0.86, validation loss=0.55
# Epoch 9: 41.76s, train acc=0.86, train loss=0.52, validation acc=0.86, validation loss=0.52
# Epoch 10: 45.09s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.49
# Epoch 11: 51.03s, train acc=0.87, train loss=0.47, validation acc=0.87, validation loss=0.47
# Epoch 12: 54.38s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.45
# Epoch 13: 57.72s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.43
# Epoch 14: 61.05s, train acc=0.88, train loss=0.42, validation acc=0.88, validation loss=0.42
# Epoch 15: 67.10s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 16: 70.48s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 17: 73.78s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 18: 77.96s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 19: 82.60s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 20: 85.93s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.37
# Test Accuracy: 0.8929, Test Loss: 0.3727
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=relu, learning_rate=0.01
# Epoch 1: 2.84s, train acc=0.85, train loss=0.59, validation acc=0.85, validation loss=0.58
# Epoch 2: 7.00s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 3: 13.69s, train acc=0.91, train loss=0.34, validation acc=0.90, validation loss=0.34
# Epoch 4: 16.63s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 5: 19.42s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 26.29s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 7: 29.14s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 8: 32.05s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 9: 34.90s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.23
# Epoch 10: 40.64s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 11: 43.47s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 12: 46.47s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 13: 49.44s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 14: 54.54s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 15: 57.81s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 16: 60.78s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 17: 63.69s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 18: 68.07s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 19: 71.75s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 20: 74.68s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.15
# Test Accuracy: 0.9558, Test Loss: 0.1545
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=relu, learning_rate=0.001
# Epoch 1: 3.03s, train acc=0.32, train loss=2.17, validation acc=0.32, validation loss=2.17
# Epoch 2: 7.08s, train acc=0.62, train loss=1.93, validation acc=0.62, validation loss=1.93
# Epoch 3: 11.15s, train acc=0.72, train loss=1.60, validation acc=0.72, validation loss=1.60
# Epoch 4: 14.06s, train acc=0.76, train loss=1.26, validation acc=0.76, validation loss=1.26
# Epoch 5: 16.93s, train acc=0.79, train loss=1.01, validation acc=0.79, validation loss=1.00
# Epoch 6: 20.11s, train acc=0.81, train loss=0.83, validation acc=0.82, validation loss=0.83
# Epoch 7: 25.15s, train acc=0.83, train loss=0.72, validation acc=0.83, validation loss=0.72
# Epoch 8: 28.00s, train acc=0.84, train loss=0.65, validation acc=0.84, validation loss=0.64
# Epoch 9: 30.87s, train acc=0.85, train loss=0.59, validation acc=0.85, validation loss=0.59
# Epoch 10: 33.74s, train acc=0.86, train loss=0.55, validation acc=0.86, validation loss=0.55
# Epoch 11: 39.62s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.51
# Epoch 12: 42.52s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.49
# Epoch 13: 45.42s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.47
# Epoch 14: 48.27s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.45
# Epoch 15: 53.62s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.43
# Epoch 16: 56.51s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 17: 59.39s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 18: 62.31s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 19: 67.08s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 20: 70.50s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.38
# Test Accuracy: 0.8946, Test Loss: 0.3862
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=sigmoid, learning_rate=0.01
# Epoch 1: 3.57s, train acc=0.15, train loss=2.27, validation acc=0.15, validation loss=2.27
# Epoch 2: 7.17s, train acc=0.28, train loss=2.24, validation acc=0.28, validation loss=2.24
# Epoch 3: 13.63s, train acc=0.41, train loss=2.18, validation acc=0.41, validation loss=2.18
# Epoch 4: 17.24s, train acc=0.52, train loss=2.06, validation acc=0.52, validation loss=2.06
# Epoch 5: 20.90s, train acc=0.55, train loss=1.85, validation acc=0.55, validation loss=1.85
# Epoch 6: 26.94s, train acc=0.58, train loss=1.60, validation acc=0.57, validation loss=1.59
# Epoch 7: 30.65s, train acc=0.64, train loss=1.38, validation acc=0.64, validation loss=1.37
# Epoch 8: 34.22s, train acc=0.68, train loss=1.20, validation acc=0.68, validation loss=1.20
# Epoch 9: 38.16s, train acc=0.71, train loss=1.06, validation acc=0.71, validation loss=1.06
# Epoch 10: 43.88s, train acc=0.75, train loss=0.94, validation acc=0.75, validation loss=0.94
# Epoch 11: 47.49s, train acc=0.77, train loss=0.85, validation acc=0.77, validation loss=0.84
# Epoch 12: 51.06s, train acc=0.79, train loss=0.77, validation acc=0.79, validation loss=0.77
# Epoch 13: 57.47s, train acc=0.81, train loss=0.72, validation acc=0.81, validation loss=0.71
# Epoch 14: 61.06s, train acc=0.82, train loss=0.67, validation acc=0.82, validation loss=0.66
# Epoch 15: 64.59s, train acc=0.83, train loss=0.63, validation acc=0.83, validation loss=0.62
# Epoch 16: 68.91s, train acc=0.84, train loss=0.60, validation acc=0.84, validation loss=0.59
# Epoch 17: 74.12s, train acc=0.85, train loss=0.57, validation acc=0.85, validation loss=0.56
# Epoch 18: 77.68s, train acc=0.85, train loss=0.55, validation acc=0.85, validation loss=0.54
# Epoch 19: 81.30s, train acc=0.86, train loss=0.53, validation acc=0.86, validation loss=0.52
# Epoch 20: 87.39s, train acc=0.86, train loss=0.51, validation acc=0.86, validation loss=0.50
# Test Accuracy: 0.8631, Test Loss: 0.5039
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=sigmoid, learning_rate=0.001
# Epoch 1: 3.52s, train acc=0.12, train loss=2.30, validation acc=0.12, validation loss=2.30
# Epoch 2: 7.02s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 11.77s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 16.24s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 5: 19.64s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 6: 23.19s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 7: 29.32s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 8: 32.82s, train acc=0.14, train loss=2.27, validation acc=0.14, validation loss=2.27
# Epoch 9: 36.30s, train acc=0.17, train loss=2.27, validation acc=0.18, validation loss=2.27
# Epoch 10: 40.88s, train acc=0.19, train loss=2.27, validation acc=0.19, validation loss=2.27
# Epoch 11: 45.46s, train acc=0.19, train loss=2.26, validation acc=0.19, validation loss=2.26
# Epoch 12: 51.65s, train acc=0.21, train loss=2.26, validation acc=0.21, validation loss=2.26
# Epoch 13: 57.42s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 14: 60.90s, train acc=0.28, train loss=2.25, validation acc=0.28, validation loss=2.25
# Epoch 15: 64.46s, train acc=0.27, train loss=2.24, validation acc=0.28, validation loss=2.24
# Epoch 16: 68.51s, train acc=0.29, train loss=2.24, validation acc=0.29, validation loss=2.24
# Epoch 17: 73.82s, train acc=0.30, train loss=2.23, validation acc=0.30, validation loss=2.23
# Epoch 18: 77.32s, train acc=0.32, train loss=2.23, validation acc=0.32, validation loss=2.23
# Epoch 19: 80.86s, train acc=0.35, train loss=2.22, validation acc=0.35, validation loss=2.22
# Epoch 20: 87.28s, train acc=0.35, train loss=2.22, validation acc=0.35, validation loss=2.22
# Test Accuracy: 0.3553, Test Loss: 2.2169
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=tanh, learning_rate=0.01
# Epoch 1: 5.04s, train acc=0.86, train loss=0.57, validation acc=0.86, validation loss=0.57
# Epoch 2: 10.49s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 3: 17.46s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 4: 22.56s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.32
# Epoch 5: 30.43s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.30
# Epoch 6: 35.52s, train acc=0.92, train loss=0.29, validation acc=0.92, validation loss=0.29
# Epoch 7: 42.18s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.28
# Epoch 8: 47.91s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 9: 53.09s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.26
# Epoch 10: 61.02s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 11: 66.14s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 12: 74.01s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 13: 79.12s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 14: 84.54s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 15: 91.83s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.22
# Epoch 16: 97.09s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 17: 104.89s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 18: 109.89s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 19: 116.81s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 20: 122.04s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Test Accuracy: 0.9414, Test Loss: 0.2008
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=tanh, learning_rate=0.001
# Epoch 1: 4.96s, train acc=0.64, train loss=1.77, validation acc=0.63, validation loss=1.77
# Epoch 2: 12.82s, train acc=0.74, train loss=1.38, validation acc=0.73, validation loss=1.37
# Epoch 3: 17.94s, train acc=0.79, train loss=1.11, validation acc=0.78, validation loss=1.10
# Epoch 4: 25.51s, train acc=0.81, train loss=0.93, validation acc=0.81, validation loss=0.92
# Epoch 5: 30.57s, train acc=0.83, train loss=0.81, validation acc=0.83, validation loss=0.81
# Epoch 6: 35.95s, train acc=0.84, train loss=0.73, validation acc=0.84, validation loss=0.72
# Epoch 7: 42.85s, train acc=0.85, train loss=0.66, validation acc=0.85, validation loss=0.66
# Epoch 8: 47.90s, train acc=0.86, train loss=0.62, validation acc=0.86, validation loss=0.61
# Epoch 9: 55.68s, train acc=0.86, train loss=0.58, validation acc=0.86, validation loss=0.57
# Epoch 10: 60.63s, train acc=0.87, train loss=0.55, validation acc=0.87, validation loss=0.54
# Epoch 11: 66.43s, train acc=0.87, train loss=0.52, validation acc=0.87, validation loss=0.52
# Epoch 12: 72.83s, train acc=0.88, train loss=0.50, validation acc=0.87, validation loss=0.50
# Epoch 13: 78.00s, train acc=0.88, train loss=0.48, validation acc=0.88, validation loss=0.48
# Epoch 14: 85.54s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 15: 90.68s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.45
# Epoch 16: 97.73s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.44
# Epoch 17: 103.01s, train acc=0.89, train loss=0.43, validation acc=0.89, validation loss=0.43
# Epoch 18: 108.12s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 19: 118.30s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 20: 123.55s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Test Accuracy: 0.8912, Test Loss: 0.3999
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 3.36s, train acc=0.86, train loss=0.57, validation acc=0.86, validation loss=0.56
# Epoch 2: 8.46s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 3: 11.58s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.33
# Epoch 4: 14.62s, train acc=0.92, train loss=0.30, validation acc=0.92, validation loss=0.30
# Epoch 5: 18.48s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 6: 23.39s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.26
# Epoch 7: 26.47s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 8: 29.63s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 9: 34.44s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 10: 38.88s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 11: 42.17s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 12: 45.56s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.19
# Epoch 13: 51.58s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 14: 54.81s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 15: 58.07s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 16: 61.27s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 17: 67.14s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.15
# Epoch 18: 70.20s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 19: 73.42s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 20: 76.67s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Test Accuracy: 0.9573, Test Loss: 0.1495
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 5.66s, train acc=0.49, train loss=2.08, validation acc=0.49, validation loss=2.08
# Epoch 2: 8.82s, train acc=0.66, train loss=1.78, validation acc=0.67, validation loss=1.78
# Epoch 3: 11.92s, train acc=0.73, train loss=1.41, validation acc=0.73, validation loss=1.41
# Epoch 4: 15.55s, train acc=0.77, train loss=1.11, validation acc=0.77, validation loss=1.10
# Epoch 5: 20.70s, train acc=0.80, train loss=0.90, validation acc=0.80, validation loss=0.90
# Epoch 6: 23.76s, train acc=0.82, train loss=0.77, validation acc=0.82, validation loss=0.77
# Epoch 7: 26.81s, train acc=0.83, train loss=0.68, validation acc=0.83, validation loss=0.68
# Epoch 8: 29.93s, train acc=0.84, train loss=0.62, validation acc=0.84, validation loss=0.62
# Epoch 9: 35.29s, train acc=0.85, train loss=0.57, validation acc=0.85, validation loss=0.57
# Epoch 10: 38.32s, train acc=0.86, train loss=0.54, validation acc=0.86, validation loss=0.53
# Epoch 11: 41.33s, train acc=0.87, train loss=0.51, validation acc=0.87, validation loss=0.50
# Epoch 12: 44.57s, train acc=0.87, train loss=0.48, validation acc=0.87, validation loss=0.48
# Epoch 13: 49.65s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 14: 52.71s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.44
# Epoch 15: 55.59s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.43
# Epoch 16: 58.75s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 17: 63.90s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.40
# Epoch 18: 67.03s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.39
# Epoch 19: 70.09s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 20: 73.24s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.38
# Test Accuracy: 0.8966, Test Loss: 0.3813
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=selu, learning_rate=0.01
# Epoch 1: 6.11s, train acc=0.88, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 2: 9.89s, train acc=0.90, train loss=0.34, validation acc=0.90, validation loss=0.34
# Epoch 3: 13.58s, train acc=0.91, train loss=0.31, validation acc=0.91, validation loss=0.31
# Epoch 4: 20.10s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.30
# Epoch 5: 23.85s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.29
# Epoch 6: 27.56s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 7: 33.75s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 8: 37.61s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.26
# Epoch 9: 41.45s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 10: 46.53s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 11: 51.87s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 12: 55.78s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 13: 59.89s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.22
# Epoch 14: 66.12s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 15: 69.86s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 16: 73.68s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 17: 80.36s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 18: 84.14s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 19: 87.94s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.19
# Epoch 20: 94.46s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Test Accuracy: 0.9456, Test Loss: 0.1881
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=selu, learning_rate=0.001
# Epoch 1: 3.70s, train acc=0.72, train loss=1.34, validation acc=0.72, validation loss=1.34
# Epoch 2: 10.67s, train acc=0.80, train loss=0.93, validation acc=0.80, validation loss=0.92
# Epoch 3: 16.48s, train acc=0.83, train loss=0.74, validation acc=0.83, validation loss=0.74
# Epoch 4: 20.29s, train acc=0.85, train loss=0.64, validation acc=0.84, validation loss=0.63
# Epoch 5: 24.10s, train acc=0.86, train loss=0.57, validation acc=0.86, validation loss=0.57
# Epoch 6: 30.30s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.52
# Epoch 7: 33.98s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.49
# Epoch 8: 37.64s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 9: 44.03s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.44
# Epoch 10: 47.74s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.42
# Epoch 11: 51.57s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 12: 57.06s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 13: 61.28s, train acc=0.90, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 14: 65.00s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.38
# Epoch 15: 68.94s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.37
# Epoch 16: 74.74s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.36
# Epoch 17: 78.55s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.36
# Epoch 18: 82.23s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 19: 88.67s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.35
# Epoch 20: 92.47s, train acc=0.90, train loss=0.34, validation acc=0.90, validation loss=0.34
# Test Accuracy: 0.9043, Test Loss: 0.3427
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=elu, learning_rate=0.01
# Epoch 1: 3.73s, train acc=0.86, train loss=0.51, validation acc=0.86, validation loss=0.51
# Epoch 2: 10.36s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.38
# Epoch 3: 14.11s, train acc=0.90, train loss=0.34, validation acc=0.90, validation loss=0.34
# Epoch 4: 17.89s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.32
# Epoch 5: 24.22s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 6: 27.76s, train acc=0.92, train loss=0.29, validation acc=0.92, validation loss=0.30
# Epoch 7: 31.42s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.29
# Epoch 8: 36.01s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.28
# Epoch 9: 41.20s, train acc=0.93, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 10: 44.78s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.27
# Epoch 11: 48.58s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.26
# Epoch 12: 54.98s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.26
# Epoch 13: 58.58s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 14: 62.34s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.25
# Epoch 15: 68.54s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 16: 71.94s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 17: 75.42s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.23
# Epoch 18: 79.13s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.23
# Epoch 19: 85.04s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.22
# Epoch 20: 88.78s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Test Accuracy: 0.9383, Test Loss: 0.2165
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=momentum, activation=elu, learning_rate=0.001
# Epoch 1: 3.71s, train acc=0.61, train loss=1.78, validation acc=0.61, validation loss=1.78
# Epoch 2: 10.88s, train acc=0.73, train loss=1.36, validation acc=0.73, validation loss=1.36
# Epoch 3: 16.81s, train acc=0.78, train loss=1.06, validation acc=0.78, validation loss=1.06
# Epoch 4: 21.95s, train acc=0.81, train loss=0.87, validation acc=0.81, validation loss=0.86
# Epoch 5: 26.75s, train acc=0.83, train loss=0.74, validation acc=0.83, validation loss=0.74
# ...
# Epoch 8: 59.77s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.15
# Epoch 9: 65.95s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.15
# Epoch 10: 74.43s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.16
# Epoch 11: 80.60s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.17
# Epoch 12: 91.53s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.17
# Epoch 13: 99.55s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.17
# Epoch 14: 105.39s, train acc=0.99, train loss=0.02, validation acc=0.96, validation loss=0.17
# Epoch 15: 112.69s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.17
# Epoch 16: 119.54s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.18
# Epoch 17: 126.06s, train acc=0.99, train loss=0.02, validation acc=0.96, validation loss=0.17
# Epoch 18: 133.63s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.17
# Epoch 19: 139.99s, train acc=0.99, train loss=0.02, validation acc=0.96, validation loss=0.17
# Epoch 20: 147.85s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.20
# Test Accuracy: 0.9578, Test Loss: 0.2028
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=tanh, learning_rate=0.001
# Epoch 1: 6.25s, train acc=0.93, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 2: 14.19s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 3: 20.20s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.17
# Epoch 4: 28.69s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 5: 34.50s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.15
# Epoch 6: 43.06s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.14
# Epoch 7: 48.73s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.12
# Epoch 8: 57.18s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.12
# Epoch 9: 63.13s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.12
# Epoch 10: 71.68s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 11: 77.65s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 12: 86.26s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 13: 92.18s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 14: 100.94s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 15: 106.97s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 16: 115.41s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 17: 121.61s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 18: 130.21s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 19: 136.17s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 20: 144.79s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Test Accuracy: 0.9694, Test Loss: 0.1054
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 3.99s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 2: 8.32s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 3: 14.41s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 4: 18.34s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 5: 22.38s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 6: 28.80s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 7: 32.72s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 8: 36.80s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 9: 43.83s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 10: 47.95s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 11: 54.94s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 12: 60.82s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 13: 64.78s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 14: 69.00s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 15: 75.10s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 16: 79.20s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.14
# Epoch 17: 83.40s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 18: 89.61s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.15
# Epoch 19: 93.44s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.18
# Epoch 20: 97.31s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.16
# Test Accuracy: 0.9740, Test Loss: 0.1643
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 6.52s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 2: 10.54s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 3: 14.55s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
# Epoch 4: 21.45s, train acc=0.97, train loss=0.09, validation acc=0.97, validation loss=0.11
# Epoch 5: 25.55s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 6: 29.61s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 7: 36.23s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.09
# Epoch 8: 40.33s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.09
# Epoch 9: 44.36s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.09
# Epoch 10: 50.76s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 11: 54.70s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 12: 58.52s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 13: 65.05s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.09
# Epoch 14: 68.95s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 15: 73.04s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.09
# Epoch 16: 79.80s, train acc=1.00, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 17: 83.87s, train acc=1.00, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 18: 87.88s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 19: 94.68s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 20: 98.77s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Test Accuracy: 0.9775, Test Loss: 0.0889
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=selu, learning_rate=0.01
# Epoch 1: 5.37s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 2: 11.81s, train acc=0.97, train loss=0.08, validation acc=0.97, validation loss=0.12
# Epoch 3: 16.34s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 4: 23.54s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 5: 28.18s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 6: 32.90s, train acc=0.98, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 7: 39.79s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.14
# Epoch 8: 44.55s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 9: 50.78s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 10: 56.64s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 11: 61.50s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 12: 68.92s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 13: 73.53s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 14: 78.58s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 15: 85.28s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 16: 90.09s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.16
# Epoch 17: 97.24s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 18: 102.09s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 19: 106.88s, train acc=0.99, train loss=0.05, validation acc=0.96, validation loss=0.22
# Epoch 20: 116.12s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.18
# Test Accuracy: 0.9743, Test Loss: 0.1764
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=selu, learning_rate=0.001
# Epoch 1: 4.98s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.24
# Epoch 2: 11.74s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 3: 16.78s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.16
# Epoch 4: 21.32s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.15
# Epoch 5: 28.53s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
# Epoch 6: 33.34s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.12
# Epoch 7: 39.76s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.12
# Epoch 8: 45.39s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 9: 50.18s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 10: 57.57s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 11: 62.40s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 12: 67.59s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 13: 74.13s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 14: 78.87s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.09
# Epoch 15: 86.26s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 16: 90.94s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 17: 95.64s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 18: 103.31s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 19: 108.23s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 20: 115.15s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.09
# Test Accuracy: 0.9726, Test Loss: 0.0991
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=elu, learning_rate=0.01
# Epoch 1: 4.79s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 2: 9.58s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.12
# Epoch 3: 16.71s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.12
# Epoch 4: 21.61s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 5: 29.03s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 6: 33.63s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.13
# Epoch 7: 38.36s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.14
# Epoch 8: 45.71s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 9: 50.39s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 10: 56.47s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 11: 61.93s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.14
# Epoch 12: 66.57s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.18
# Epoch 13: 74.01s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.16
# Epoch 14: 78.73s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 15: 84.11s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 16: 90.37s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.17
# Epoch 17: 95.10s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 18: 102.62s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 19: 107.29s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.18
# Epoch 20: 111.91s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.20
# Test Accuracy: 0.9678, Test Loss: 0.1908
# ----------------------------------------------------------------------------------------------------
# Training with optimizer=adam, activation=elu, learning_rate=0.001
# Epoch 1: 7.22s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# Epoch 2: 11.87s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 3: 20.88s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 4: 26.30s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.15
# Epoch 5: 31.08s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
# Epoch 6: 38.57s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.12
# Epoch 7: 43.29s, train acc=0.97, train loss=0.09, validation acc=0.97, validation loss=0.11
# Epoch 8: 48.65s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.11
# Epoch 9: 55.41s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 10: 60.18s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 11: 67.63s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 12: 72.40s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 13: 77.38s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 14: 84.47s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.09
# Epoch 15: 89.27s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.09
# Epoch 16: 96.67s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 17: 101.17s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 18: 105.98s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 19: 113.16s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 20: 117.96s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Test Accuracy: 0.9719, Test Loss: 0.0977
# ----------------------------------------------------------------------------------------------------
# Best Configuration:
# Optimizer              adam
# Activation       leaky_relu
# Learning Rate         0.001
# Test Accuracy        0.9775
# Test Loss          0.088909
# Name: 31, dtype: object

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = input_data[:, 0]

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, len(x_points))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j + 1] - target_labels[j]) / (input_data[j + 1] - input_data[j])
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map.numpy(), predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
      layer = nn.Linear(in_num, hidden_unit_nums[i])
      self.mlp.add_module(f"Hidden_Linear_{i + 1}", layer)
      if activation_fn == "relu":
          self.mlp.add_module(f"Activation_{i + 1}", nn.ReLU())
      elif activation_fn == "sigmoid":
          self.mlp.add_module(f"Activation_{i + 1}", nn.Sigmoid())
      elif activation_fn == "softmax":
          self.mlp.add_module(f"Activation_{i + 1}", nn.Softmax())
      elif activation_fn == "tanh":
          self.mlp.add_module(f"Activation_{i + 1}", nn.Tanh())
      elif activation_fn == "leaky_relu":
          self.mlp.add_module(f"Activation_{i + 1}", nn.LeakyReLU())
      elif activation_fn == "elu":
          self.mlp.add_module(f"Activation_{i + 1}", nn.ELU())
      elif activation_fn == "selu":
        self.mlp.add_module(f"Activation_{i + 1}", nn.SELU())
      else:
          raise ValueError(f"Unsupported activation function: {activation_fn}")
      in_num = hidden_unit_nums[i]

    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)
    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    N, D = X.shape
    terms = []
    for n in range(poly_degree + 1):
        for m in range(n + 1):
            terms.append((n - m, m))
    terms = terms[1:]

    num_features = len(terms)
    poly_X = torch.zeros((N, num_features))

    for i, (n, m) in enumerate(terms):
        poly_X[:, i] = (X[:, 0] ** n) * (X[:, 1] ** m)

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 70.03
# Accuracy on the 800 testing samples: 68.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?
#
# #### Generalization:
# - The **wide network** shows lower accuracy on both training and testing datasets, indicating limited learning capacity and possible underfitting.
# - The **deep network** achieves significantly higher accuracy on both datasets, demonstrating its superior capacity to generalize and learn complex patterns effectively.
#
# #### Decision Boundaries:
# - The **wide network** likely produces fragmented and overly simplistic decision boundaries, failing to capture the full complexity of the data.
# - The **deep network** creates more structured and ideal decision boundaries due to its hierarchical learning, leading to better alignment with the true data distribution.
#
# #### Conclusion:
# - The **deeper model** generalizes better and achieves more ideal decision boundaries compared to the wide network, as it leverages depth to extract and combine meaningful features while avoiding underfitting.

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch(activation_fn="relu", input_feature_num=2, hidden_unit_nums=[64, 32], output_feature_num=K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 98.53
# Accuracy on the 800 testing samples: 98.25
